# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import math
from dct import *

PI = 3.141592

# %% [markdown]
# # 1. Load Image

# %%
image = cv2.imread('Lenna512.png', cv2.IMREAD_GRAYSCALE)
print(image.shape)
fig = plt.gcf()
fig.set_figheight(10)
fig.set_figwidth(10)
plt.imshow(image, cmap='gray')
plt.show()
# Out:
# (512, 512)

# %% [markdown]
# # 2. Demo of DCT and Inverse-DCT

# %%
# Try slide example and get the exact result.
a = np.array([[8,5],[3,4]])
print(dct_block(a))
# Out:
# [[10.  1.]
#  [ 3.  2.]]

# %%
# %time image_dct = dct_manual(image, 8)
plot_save(image_dct, 'dct_original_image_result.png', 10)
# Out:
# Wall time: 1min 10s

# %%
# %time result1 = idct_manual(image_dct, 8)
plot_save(result1, 'original_idct_final_image_result.png', 10)
# Out:
# Wall time: 54.3 s

# %%
#To check, PSNR should be 100 or MSE = 0
dct_psnr(image, result1)
# Out:
# PSNR: 100

# %% [markdown]
# # 3. Demo of Fast-DCT and Inverse-DCT

# %%
# %time image_dct2 = fast_dct_manual(image, 8)
# Out:
# Wall time: 10.4 s

# %%
plot_save(image_dct2, 'fast_DCT_image_result.png', 10)

# %%
# %time result2 = idct_manual(image_dct2, 8)
plot_save(result2, 'fast_IDCT.png', 10)
# Out:
# Wall time: 55.7 s

# %%
#To check, PSNR should be 100 or MSE = 0
dct_psnr(image, result2)
# Out:
# PSNR: 100
